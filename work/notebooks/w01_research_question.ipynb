# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/usman-stack-322/flyrank-ml-internship-v2/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## My Lane
#
# I selected the **Content Opportunity Scoring** lane.
#
# I chose this lane because it helps identify which web pages have the highest potential for improvement. Instead of updating every page, the model can rank pages so the SEO team can focus on the pages most likely to benefit from content updates.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/usman-stack-322/flyrank-ml-internship-v2"
REPO_DIR = "flyrank-ml-internship-v2"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)

print("Current directory:", os.getcwd())
print("Dataset exists:", os.path.exists("data/raw/content_refresh_anonymized.csv"))
# Out:
# Current directory: /content/flyrank-ml-internship-v2
# Dataset exists: True

# %% [markdown]
# ## Research Question
#
# **Question:** Which web pages should be prioritized for content refresh?
#
# **Unit of Analysis:** One web page.
#
# **Output:** A ranked list of pages with the highest opportunity score.
#
# **Decision:** Decide which pages should be updated first.
#
# **Action:** The SEO/content team updates the selected pages.
#
# **Cost of a Wrong Recommendation:** Time and effort may be wasted on low-impact pages while important pages are ignored.
#
# **Why ML:** Machine learning can combine multiple SEO signals better than simple manual rules.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])
print("Average CTR:", round(df["ctr"].mean(), 4))
print("Average Search Volume:", round(df["search_volume"].mean(), 2))
print("Average Impressions:", round(df["impressions_90d"].mean(), 2))
# Out:
# Rows: 30000
# Columns: 44
# Average CTR: 0.5107
# Average Search Volume: 158.88
# Average Impressions: 5200.37

# %% [markdown]
# ## Careful Words
#
# This project provides decision support based on observed patterns in historical SEO data.
#
# It does not prove that refreshing a page will definitely improve rankings or traffic, and it does not predict Google's algorithm.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# - [x] Every section above is filled ...
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
